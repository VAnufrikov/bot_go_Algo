# %%
from news_regressor import NewsRegressor

ticket = '$GMKN'
date = '2023-07-06 18:31:24'

NR = NewsRegressor()
NR.predict(ticket=ticket, date=date)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 6
#       3 ticket = '$GMKN'
#       4 date = '2023-07-06 18:31:24'
# ----> 6 NR = NewsRegressor()
#       7 NR.predict(ticket=ticket, date=date)
#
# File ~/PycharmProjects/bot_go_Algo/news_regressor/news_regressor.py:11, in NewsRegressor.__init__(self)
#      10 def __init__(self):
# ---> 11     self.df = pd.read_excel("news_regressor/news.xlsx")[
#      12         ["date", "news", "proc", "ticket"]
#      13     ]
#      14     self.vectorizer = SentenceTransformer("cointegrated/rubert-tiny2")
#
# File ~/anaconda3/envs/Go_Algo_bot/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in wrapper(*args, **kwargs)
#     206     if kwargs.get(new_arg_name) is not None:
#     207         msg = (
#     208             f"Can only specify {repr(old_arg_name)} "
# ...
